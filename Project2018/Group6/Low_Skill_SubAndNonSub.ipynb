# %%
import requests
import pandas as pd

Low_skill_list_nonsub = ["213648575", "172903224", "130245670", "204526534", "220638647", "116924925" ,"132211352" ,"178896558"]
Low_skill_list_sub = ["336333581" ,"383650106","387666830","336333581","142089632"]

ls_wl_nonsub=[]
ls_win_nonsub = []
ls_loss_nonsub = []
ls_matches_nonsub = []
ls_heroes_nonsub = []
Hero_ID=[]
Last_Played= []
Games = []
Win = []
With_Games = []
With_Win = []
Against_Games = []
Against_Win = []
Match_ID = []
Status = []
Duration = []
Hero_ID2 = []
Kills = []
Deaths = []
Assists =[]
Player_ID = []
Player_ID2 = []


for i in range(0,8):
    
    str1 = 'https://api.opendota.com/api/players/'+ Low_skill_list_nonsub[i]+'/wl?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    str2 = 'https://api.opendota.com/api/players/'+ Low_skill_list_nonsub[i]+'/heroes?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    str3 = 'https://api.opendota.com/api/players/'+ Low_skill_list_nonsub[i]+'/matches?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    

    
    r1 = requests.get(str1)
    ls_win_nonsub.append(r1.json()['win'])
    ls_loss_nonsub.append(r1.json()['lose'])
    r2 = requests.get(str2)
    for j in range(0,116):
        Hero_ID.append(r2.json()[j]['hero_id'])
        Last_Played.append(r2.json()[j]['last_played'])
        Games.append(r2.json()[j]['games'])
        Win.append(r2.json()[j]['win'])
        With_Games.append(r2.json()[j]['with_games'])
        With_Win.append(r2.json()[j]['with_win'])
        Against_Games.append(r2.json()[j]['against_games'])
        Against_Win.append(r2.json()[j]['against_win'])
        Player_ID.append(Low_skill_list_nonsub[i])
        

    
    r3 = requests.get(str3)
    for j in range(0,200):
        Match_ID.append(r3.json()[j]['match_id'])
        Status.append(r3.json()[j]['radiant_win'])
        Duration.append(r3.json()[j]['duration'])
        Hero_ID2.append(r3.json()[j]['hero_id'])
        Kills.append(r3.json()[j]['kills'])
        Deaths.append(r3.json()[j]['deaths'])
        Assists.append(r3.json()[j]['assists'])
        Player_ID2.append(Low_skill_list_nonsub[i])
    
    
    

a = zip(Hero_ID,Last_Played,Games, Win, With_Games,With_Win, Against_Games, Against_Win,Player_ID)
a = list(a)
ls_heroes_nonsub = pd.DataFrame(a)

d = zip(Match_ID, Status,Duration,Hero_ID2, Kills, Deaths, Assists,Player_ID2)

d = list(d)  
ls_matches_nonsub =pd.DataFrame(d)
    
    
ls_heroes_nonsub.rename(columns={0: 'Hero_ID', 1: 'Last Played', 2:'Games', 3:'Win',4: 'With Games',5:'With win',6:'Against Games',7:'Against Win',8:'Player ID'})    
    
ls_matches_nonsub.rename(columns={0: 'Match_ID', 1: 'Status', 2:'Duration', 3:'Hero ID',4: 'Kills',5:'Deaths',6:'Assists',7:'Player ID'})    

   
c = zip(Low_skill_list_nonsub,ls_win_nonsub,ls_loss_nonsub)
c = list(c)

ls_wl_nonsub = pd.DataFrame(c)
ls_wl_nonsub.rename(columns={0:'Player ID',1:'Win',2:'Loss'})
# Out:
#    Player ID   Win  Loss
# 0  213648575   604   510
# 1  172903224   838   838
# 2  130245670   893   734
# 3  204526534   519   427
# 4  220638647   791   919
# 5  116924925   656   543
# 6  132211352  1475  1499
# 7  178896558   721   550

# %%
ls_heroes_nonsub= ls_heroes_nonsub.rename(columns={0: 'Hero_ID', 1: 'Last Played', 2:'Games', 3:'Win',4: 'With Games',5:'With win',6:'Against Games',7:'Against Win',8:'Player ID'})    
    
ls_matches_nonsub=ls_matches_nonsub.rename(columns={0: 'Match_ID', 1: 'Status', 2:'Duration', 3:'Hero ID',4: 'Kills',5:'Deaths',6:'Assists',7:'Player ID'})

# %%
Hero_ID=[]
Last_Played= []
Games = []
Win = []
With_Games = []
With_Win = []
Against_Games = []
Against_Win = []
Match_ID = []
Status = []
Duration = []
Hero_ID2 = []
Kills = []
Deaths = []
Assists =[]
Player_ID = []
Player_ID2 = []
ls_win_sub =[]
ls_loss_sub =[]
Player_ID3 = []



for i in range(0,5):
    
    str1 = 'https://api.opendota.com/api/players/'+ Low_skill_list_sub[i]+'/wl?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    str2 = 'https://api.opendota.com/api/players/'+ Low_skill_list_sub[i]+'/heroes?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    str3 = 'https://api.opendota.com/api/players/'+ Low_skill_list_sub[i]+'/matches?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    
   
    
    r1 = requests.get(str1)
    ls_win_sub.append(r1.json()['win'])
    ls_loss_sub.append(r1.json()['lose'])
    
    r2 = requests.get(str2)
    for j in range(0,116):
        Hero_ID.append(r2.json()[j]['hero_id'])
        Last_Played.append(r2.json()[j]['last_played'])
        Games.append(r2.json()[j]['games'])
        Win.append(r2.json()[j]['win'])
        With_Games.append(r2.json()[j]['with_games'])
        With_Win.append(r2.json()[j]['with_win'])
        Against_Games.append(r2.json()[j]['against_games'])
        Against_Win.append(r2.json()[j]['against_win'])
        Player_ID.append(Low_skill_list_sub[i])
        
    
    
    r3 = requests.get(str3)
    for j in range(0,200):
        Match_ID.append(r3.json()[j]['match_id'])
        Status.append(r3.json()[j]['radiant_win'])
        Duration.append(r3.json()[j]['duration'])
        Hero_ID2.append(r3.json()[j]['hero_id'])
        Kills.append(r3.json()[j]['kills'])
        Deaths.append(r3.json()[j]['deaths'])
        Assists.append(r3.json()[j]['assists'])
        Player_ID2.append(Low_skill_list_sub[i])
        
    
    

a = zip(Hero_ID,Last_Played,Games, Win, With_Games,With_Win, Against_Games, Against_Win,Player_ID)
a = list(a)
ls_heroes_sub = pd.DataFrame(a)

d = zip(Match_ID, Status,Duration,Hero_ID2, Kills, Deaths, Assists,Player_ID2)

d = list(d)  
ls_matches_sub =pd.DataFrame(d)
    
    
c = zip(Low_skill_list_sub,ls_win_sub,ls_loss_sub)
c = list(c)

ls_wl_sub = pd.DataFrame(c)
ls_wl_sub.rename(columns={0:'Player ID',1:'Win',2:'Loss'})
# Out:
#    Player ID   Win  Loss
# 0  336333581   973   851
# 1  383650106   701   710
# 2  387666830  1133  1017
# 3  336333581   973   851
# 4  142089632  1867  1925

# %%
ls_matches_sub= ls_matches_sub.rename(columns={0: 'Match_ID', 1: 'Status', 2:'Duration', 3:'Hero ID',4: 'Kills',5:'Deaths',6:'Assists',7:'Player ID'})

# %%
ls_heroes_sub = ls_heroes_sub.rename(columns={0: 'Hero_ID', 1: 'Last Played', 2:'Games', 3:'Win',4: 'With Games',5:'With win',6:'Against Games',7:'Against Win',8:'Player ID'})

# %%
ls_heroes_sub.to_csv('Low Skill Sub Hero Data.csv', sep='\t', encoding='utf-8')

# %%
ls_matches_sub.to_csv('Low Skill Sub Matches Data.csv', sep = '\t', encoding = 'utf-8')

# %%
ls_heroes_nonsub.to_csv('Low Skill Non Sub Heroes Data.csv', sep = '\t', encoding = 'utf-8')

# %%
ls_matches_nonsub.to_csv('Low Skill Non Sub Match Data.csv', sep ='\t', encoding = 'utf-8')

# %%
ls_wl_nonsub.to_csv('Low Skill Non Sub Win loss.csv', sep ='\t', encoding = 'utf-8')

# %%
ls_wl_sub.to_csv('Low Skill Sub Win loss.csv', sep = '\t', encoding = 'utf-8')

# %%
ls_wl_nonsub
# Out:
#            0     1     2
# 0  213648575   604   510
# 1  172903224   838   838
# 2  130245670   893   734
# 3  204526534   519   427
# 4  220638647   791   919
# 5  116924925   656   543
# 6  132211352  1475  1499
# 7  178896558   721   550

# %%
total1=ls_wl_sub[1]+ls_wl_sub[2]
result1 = ls_wl_sub[1]/total1
total2=ls_wl_nonsub[1]+ls_wl_nonsub[2]
result2 = ls_wl_nonsub[1]/total2
result3=sorted(result1)# sub
result4=sorted(result2)# non-sub
result1
# Out:
# 0    0.533443
# 1    0.496811
# 2    0.526977
# 3    0.533443
# 4    0.492352
# dtype: float64

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,7)
plt.plot(result4)
plt.xlabel('players')
plt.ylabel('Win_percentage')
plt.title('Low_skill_Nonsub')
plt.show()

# %%
x = np.linspace(0,7)
plt.plot(result3)
plt.xlabel('players')
plt.ylabel('Win_percentage')
plt.title('Low_skill_Sub')
plt.show()

# %%
result5=result4[0:5]
x = np.linspace(0,5)
plt.plot(result3,label='Sub')
plt.plot(result5,label='non_Sub')
plt.legend(loc='upper right')
plt.xlabel('players')
plt.ylabel('Win_percentage')
plt.title('Low_skill_nonSub&Sub')
plt.show()

# %%
ls_heroes_nonsub
# Out:
#     Hero_ID  Last Played  Games  Win  With Games  With win  Against Games  \
# 0        74   1543729152     80   46          75        49             91
# 1        11   1540539956     75   42          63        33             69
# 2         2   1542440285     46   18          90        44            104
# 3        59   1542866115     45   17          67        35            104
# 4        34   1541319677     43   35          29        18             44
# 5        93   1540131693     42   23          75        47             82
# 6         4   1535826782     41   21         100        61            122
# 7        17   1542878926     39   18          31        21             52
# 8        26   1464810291     36   19         117        58             62
# 9        21   1466934636     26   13          97        53            121
# 10        1   1542701723     26   13          62        36             88
# 11      104   1541700688     25   13         120        66            102
# ...

# %%
ls_heroes_nonsub['Win percentage'] = ls_heroes_nonsub['Win']/ls_heroes_nonsub['Games']*100

# %%
ls_heroes_nonsub
# Out:
#     Hero_ID  Last Played  Games  Win  With Games  With win  Against Games  \
# 0        74   1543729152     80   46          75        49             91
# 1        11   1540539956     75   42          63        33             69
# 2         2   1542440285     46   18          90        44            104
# 3        59   1542866115     45   17          67        35            104
# 4        34   1541319677     43   35          29        18             44
# 5        93   1540131693     42   23          75        47             82
# 6         4   1535826782     41   21         100        61            122
# 7        17   1542878926     39   18          31        21             52
# 8        26   1464810291     36   19         117        58             62
# 9        21   1466934636     26   13          97        53            121
# 10        1   1542701723     26   13          62        36             88
# 11      104   1541700688     25   13         120        66            102
# ...

# %%
ls_heroes_sub['Win percentage'] = ls_heroes_sub['Win']/ls_heroes_sub['Games']*100

# %%
a = ls_heroes_sub.loc[ls_heroes_sub['Hero_ID']=='14']
c = sorted(a['Win percentage'])

# %%
b = ls_heroes_nonsub.loc[ls_heroes_nonsub['Hero_ID']=='14']
d = sorted(b['Win percentage'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,5)
plt.plot(c,label='Sub')
plt.plot(d,label='Non Sub')
plt.legend(loc='upper right')
plt.xlabel('Players')
plt.ylabel('Hero Win_percentage')
plt.title('Low Skill Non Subscribers and Subscribers')
plt.show()
