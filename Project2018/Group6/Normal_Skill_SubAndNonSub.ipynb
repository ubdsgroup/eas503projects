# %%
import requests
import pandas as pd

normal_skill_list_nonsub = ["145240635", "171873893", "207111394", "196011254", "201671352", "192073815" ,"158700450" ,"168480411"]
normal_skill_list_sub = ["336333581" ,"171873893", "257288601" ,"146535799" ,"293773843","157369035"]
##411975367
ns_wl_nonsub=[]
ns_win_nonsub = []
ns_loss_nonsub = []
ns_matches_nonsub = []
ns_heroes_nonsub = []
Hero_ID=[]
Last_Played= []
Games = []
Win = []
With_Games = []
With_Win = []
Against_Games = []
Against_Win = []
Match_ID = []
Status = []
Duration = []
Hero_ID2 = []
Kills = []
Deaths = []
Assists =[]
Player_ID = []
Player_ID2 = []




for i in range(0,8):
    
    str1 = 'https://api.opendota.com/api/players/'+ normal_skill_list_nonsub[i]+'/wl?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    str2 = 'https://api.opendota.com/api/players/'+ normal_skill_list_nonsub[i]+'/heroes?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    str3 = 'https://api.opendota.com/api/players/'+ normal_skill_list_nonsub[i]+'/matches?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    
   
    
    r1 = requests.get(str1)
    ns_win_nonsub.append(r1.json()['win'])
    ns_loss_nonsub.append(r1.json()['lose'])
    
    r2 = requests.get(str2)
    for j in range(0,116):
        Hero_ID.append(r2.json()[j]['hero_id'])
        Last_Played.append(r2.json()[j]['last_played'])
        Games.append(r2.json()[j]['games'])
        Win.append(r2.json()[j]['win'])
        With_Games.append(r2.json()[j]['with_games'])
        With_Win.append(r2.json()[j]['with_win'])
        Against_Games.append(r2.json()[j]['against_games'])
        Against_Win.append(r2.json()[j]['against_win'])
        Player_ID.append(normal_skill_list_nonsub[i])
        
    
    
    
    r3 = requests.get(str3)
    for j in range(0,200):
        Match_ID.append(r3.json()[j]['match_id'])
        Status.append(r3.json()[j]['radiant_win'])
        Duration.append(r3.json()[j]['duration'])
        Hero_ID2.append(r3.json()[j]['hero_id'])
        Kills.append(r3.json()[j]['kills'])
        Deaths.append(r3.json()[j]['deaths'])
        Assists.append(r3.json()[j]['assists'])
        Player_ID2.append(normal_skill_list_nonsub[i])
        


    

a = zip(Hero_ID,Last_Played,Games, Win, With_Games,With_Win, Against_Games, Against_Win,Player_ID)
a = list(a)
ns_heroes_nonsub = pd.DataFrame(a)

d = zip(Match_ID, Status,Duration,Hero_ID2, Kills, Deaths, Assists,Player_ID2)

d = list(d)  
ns_matches_nonsub =pd.DataFrame(d)
    
    

   
c = zip(normal_skill_list_nonsub,ns_win_nonsub,ns_loss_nonsub)
c = list(c)

ns_wl_nonsub = pd.DataFrame(c)

# %%
ns_heroes_nonsub= ns_heroes_nonsub.rename(columns={0: 'Hero_ID', 1: 'Last Played', 2:'Games', 3:'Win',4: 'With Games',5:'With win',6:'Against Games',7:'Against Win',8:'Player ID'})    
    
ns_matches_nonsub=ns_matches_nonsub.rename(columns={0: 'Match_ID', 1: 'Status', 2:'Duration', 3:'Hero ID',4: 'Kills',5:'Deaths',6:'Assists',7:'Player ID'})    


ns_wl_nonsub= ns_wl_nonsub.rename(columns={0:'Player ID',1:'Win',2:'Loss'})

# %%
ns_heroes_nonsub.to_csv('Normal Skill Non Sub Heroes Data.csv', sep = '\t', encoding = 'utf-8')

# %%
ns_matches_nonsub.to_csv('Normal Skill Non Sub Match Data.csv', sep ='\t', encoding = 'utf-8')

# %%
ns_wl_nonsub.to_csv('Normal Skill Non Sub Win loss.csv', sep ='\t', encoding = 'utf-8')

# %%
normal_skill_list_sub = ["336333581" ,"411975367", "257288601","171873893" ,"293773843","157369035"]

# %%
Hero_ID=[]
Last_Played= []
Games = []
Win = []
With_Games = []
With_Win = []
Against_Games = []
Against_Win = []
Match_ID = []
Status = []
Duration = []
Hero_ID2 = []
Kills = []
Deaths = []
Assists =[]
Player_ID = []
Player_ID2 = []
ns_win_sub =[]
ns_loss_sub =[]
Player_ID3 = []



for i in range(0,6):
    
    str1 = 'https://api.opendota.com/api/players/'+ normal_skill_list_sub[i]+'/wl?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    str2 = 'https://api.opendota.com/api/players/'+ normal_skill_list_sub[i]+'/heroes?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    str3 = 'https://api.opendota.com/api/players/'+ normal_skill_list_sub[i]+'/matches?api_key=1ef6df10-a6e5-4a8b-9fce-73eae6186e35'
    
   
    
    r1 = requests.get(str1)
    ns_win_sub.append(r1.json()['win'])
    ns_loss_sub.append(r1.json()['lose'])
    
    r2 = requests.get(str2)
    for j in range(0,116):
        Hero_ID.append(r2.json()[j]['hero_id'])
        Last_Played.append(r2.json()[j]['last_played'])
        Games.append(r2.json()[j]['games'])
        Win.append(r2.json()[j]['win'])
        With_Games.append(r2.json()[j]['with_games'])
        With_Win.append(r2.json()[j]['with_win'])
        Against_Games.append(r2.json()[j]['against_games'])
        Against_Win.append(r2.json()[j]['against_win'])
        Player_ID.append(normal_skill_list_sub[i])
        
    
      
    r3 = requests.get(str3)
    for j in range(0,200):
        Match_ID.append(r3.json()[j]['match_id'])
        Status.append(r3.json()[j]['radiant_win'])
        Duration.append(r3.json()[j]['duration'])
        Hero_ID2.append(r3.json()[j]['hero_id'])
        Kills.append(r3.json()[j]['kills'])
        Deaths.append(r3.json()[j]['deaths'])
        Assists.append(r3.json()[j]['assists'])
        Player_ID2.append(normal_skill_list_sub[i])
         
        


  
    

a = zip(Hero_ID,Last_Played,Games, Win, With_Games,With_Win, Against_Games, Against_Win,Player_ID)
a = list(a)
ns_heroes_sub = pd.DataFrame(a)

d = zip(Match_ID, Status,Duration,Hero_ID2, Kills, Deaths, Assists,Player_ID2)

d = list(d)  
ns_matches_sub =pd.DataFrame(d)
    
    
c = zip(normal_skill_list_sub,ns_win_sub,ns_loss_sub)
c = list(c)

ns_wl_sub = pd.DataFrame(c)

# %%
ns_matches_sub= ns_matches_sub.rename(columns={0: 'Match_ID', 1: 'Status', 2:'Duration', 3:'Hero ID',4: 'Kills',5:'Deaths',6:'Assists',7:'Player ID'})

# %%
ns_heroes_sub = ns_heroes_sub.rename(columns={0: 'Hero_ID', 1: 'Last Played', 2:'Games', 3:'Win',4: 'With Games',5:'With win',6:'Against Games',7:'Against Win',8:'Player ID'})

# %%
ns_wl_sub.rename(columns={0:'Player ID',1:'Win',2:'Loss'})
# Out:
#    Player ID   Win  Loss
# 0  336333581   973   851
# 1  411975367   467   566
# 2  257288601  2339  2402
# 3  171873893   596   532
# 4  293773843  1074   936
# 5  157369035  3177  2955

# %%
ns_heroes_sub.to_csv('Normal Skill Sub Heroes Data.csv', sep = '\t', encoding = 'utf-8')

# %%
ns_matches_sub.to_csv('Normal Skill Sub Match Data.csv', sep ='\t', encoding = 'utf-8')

# %%
ns_wl_sub.to_csv('Normal Skill Sub Win loss.csv', sep ='\t', encoding = 'utf-8')

# %%
ns_heroes_nonsub
# Out:
#     Hero_ID  Last Played  Games  Win  With Games  With win  Against Games  \
# 0        35   1541261093     70   43         167        86            199
# 1        26   1543713032     68   35         133        68            104
# 2         4   1497307418     54   30          91        48            117
# 3        64   1542580546     47   21          28        17             51
# 4        14   1542406773     35   22         186        91            280
# 5        28   1510801337     31   12          55        33             79
# 6        48   1542839972     30   19          51        28             66
# 7        59   1449563224     29    9          71        31             80
# 8        30   1524609956     27   14          69        42             74
# 9        47   1476355259     27   20         101        63             96
# 10       76   1518049644     26   11          40        18             44
# 11       53   1542567020     26   11          67        32             66
# ...

# %%
ns_heroes_nonsub['Win percentage'] = ns_heroes_nonsub['Win']/ns_heroes_nonsub['Games']*100

# %%
b= ns_heroes_nonsub.loc[ns_heroes_nonsub['Hero_ID']=='14']

# %%
c= sorted(b['Win percentage'])

# %%
c
# Out:
# [41.66666666666667,
#  44.44444444444444,
#  50.0,
#  50.0,
#  57.14285714285714,
#  57.14285714285714,
#  57.64192139737992,
#  62.857142857142854]

# %%
ns_heroes_sub['Win percentage'] = ns_heroes_sub['Win']/ns_heroes_sub['Games']*100
a = ns_heroes_sub.loc[ns_heroes_sub['Hero_ID']=='14']
d = sorted(a['Win percentage'])
d
# Out:
# [36.666666666666664,
#  41.66666666666667,
#  49.629629629629626,
#  54.23728813559322,
#  58.119658119658126,
#  59.3984962406015]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,5)
plt.plot(c,label='Non_Sub')
plt.plot(d,label='Sub')
plt.legend(loc='upper right')
plt.xlabel('Players')
plt.ylabel('Hero Win_percentage')
plt.title('Normal Skill Non Subscribers and Subscribers')
plt.show()

# %%
ns_matches_nonsub
# Out:
#         Match_ID  Status  Duration  Hero ID  Kills  Deaths  Assists  Player ID
# 0     4251364067    True      1840       17      8       2        9  145240635
# 1     4249938283    True      1812       26      4       7        6  145240635
# 2     4246190867    True      1881       17      9       5        4  145240635
# 3     4244690974   False      2928       41     15       8       16  145240635
# 4     4244653807    True      2204       17     12       1       11  145240635
# 5     4244623241    True      2302       17      9       5       13  145240635
# 6     4243064560    True      1934       99      4       7        3  145240635
# 7     4241589707   False      2073       26      5       4       13  145240635
# 8     4238006231    True      2849       50      6      14       18  145240635
# 9     4237893355    True      2447       17      7       3        3  145240635
# 10    4236089521    True      1967       41      6       6       11  145240635
# ...

# %%
plt.matshow(ns_matches_nonsub.corr())

# %%
import seaborn as sns
corr = ns_matches_nonsub.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
